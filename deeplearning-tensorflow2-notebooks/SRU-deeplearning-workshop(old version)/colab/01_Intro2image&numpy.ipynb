# %% [markdown]
# <a href="https://colab.research.google.com/github/fazelelham32/deeplearning-tensorflow2-notebooks/blob/main/deeplearning-tensorflow2-notebooks/SRU-deeplearning-workshop(old%20version)/colab/01_Intro2image%26numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">به نام خدا</div></center>
# <h1><center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">تصویر به عنوان داده</div></center></h1>

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">لود کتابخانه‌های مورد استفاده</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# برای اجرای این نوت‌بوک باید  کتابخانه ی  matplotlib و  numpy را نصب کنید.
# بدین منظور به اینترنت متصل شود و در ترمینال  دستورات زیر را بنویسید:
# </div>
# <p>pip install matplotlib</p>
# <p>pip install numpy</p>
# <p>pip install Pillow</p>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# میتوانید به جای pip از کلمه ی conda استفاده کنید. (اگر از آناکوندا استفاده میکنید.)
# </div>

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Import numpy
import numpy as np

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">لود تصویر از دیسک</div>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the image
data = np.array(plt.imread('/content/drive/MyDrive/image/sign.jpg'))

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# اگر برایتان سوال شده چرا
# </div>
# data = plt.imread('./image/sign.jpg')
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# ننوشتیم و از </div>
# np.array
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# استفاده شد. سوال و پاسخ زیر را ببینید: </div>
#
# <b>np arrays being immutable - “assignment destination is read-only”</b>
# <br>
# Since numpy version 1.16.0 ...
# <br>
#
# https://stackoverflow.com/a/54308748/4409764

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">نمایش تصویر </div>

# %%
# Display the image
plt.imshow(data)
plt.show()

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">داده تصویری </div>

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# نگاهی به اندازه ماتریس خوانده شده بیندازیم!
# </div>

# %%
data.shape
# Out:
# (2832, 4256, 3)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# مقدار پیکسل یک سلول خاص</div>

# %%
data[1000, 1100]
# Out:
# array([189,  28,  43], dtype=uint8)

# %%
data[250, 3500]
# Out:
# array([ 66, 112, 197], dtype=uint8)

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">ویرایش داده تصویری </div>

# %%
data[:, :, 1] = 0
data[:, :, 2] = 0
plt.imshow(data)
plt.show()

# %%
# Load the image
data = np.array(plt.imread('/content/drive/MyDrive/image/sign.jpg'))


# Set the red channel in this part of the image to 0
data[0:1000, 0:1000, 0] = 0

# Set the green channel in this part of the image to 255
data[0:1000, 0:1000, 1] = 255

# Set the blue channel in this part of the image to 0
data[0:1000, 0:1000, 2] = 0

# Visualize the result
plt.imshow(data)
plt.show()

# %% [markdown]
# [link text](https://)## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma"> تصاویر سطح خاکستری  </div>

# %% [markdown]
# \\\<div style="direction:rtl;text-align:right;font-family:Tahoma">
# تابع زیر یک تابع ساده برای تبدیل تصویر به سطح خاکستری(grayscale) است.</div>
# [stackoverflow](https://stackoverflow.com/questions/12201577/how-can-i-convert-an-rgb-image-into-grayscale-in-python)

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114]).astype(int)

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# خواندن یک تصویر به صورت سطح خاکستری</div>

# %%
img = np.array(plt.imread('/content/drive/MyDrive/image/t-shirt.jpg'))
tshirt = rgb2gray(img)

# %% [markdown]
# ```
# `# This is formatted as code`
# ```
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# اندازه ماتریس خوانده شده</div>

# %%
tshirt.shape
# Out:
# (654, 654)

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# نمایش تصویر</div>

# %%
plt.imshow(tshirt, cmap = plt.get_cmap('gray'))
plt.show()

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# مشاهده مقدار یک پیکسل خاص</div>

# %%
tshirt[250, 200]
# Out:
# np.int64(151)

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">ویرایش تصویر</div>

# %%
tshirt[200:400, 300:400]=0
plt.imshow(tshirt, cmap = plt.get_cmap('gray'))
plt.show()
